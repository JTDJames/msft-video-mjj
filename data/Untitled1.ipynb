# %%
# !ls
# Out:
# Untitled.ipynb       im.db                tmdb.movies.csv
# Untitled1.ipynb      rt.movie_info.tsv    tn.movie_budgets.csv
# bom.movie_gross.csv  rt.reviews.tsv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3

# %%
df_tn = pd.read_csv('tn.movie_budgets.csv')

# %%
conn = sqlite3.connect('../data/im.db')

# %%
#Access IMDB data through sqlite3

# Connect to sqlite3
conn = sqlite3.connect('../data/im.db')

# Query and join IMDB tables movie_basics and movie_ratings

# %%
df_tn.sort_values('worldwide_gross', ascending=False)
# Out:
#       id  release_date                                              movie  \
# 3737  38  Aug 21, 2009                             Fifty Dead Men Walking
# 3432  33  Sep 30, 2005                                               Duma
# 5062  63   Apr 1, 2011                                          Insidious
# 883   84   Apr 2, 2004                                            Hellboy
# 5613  14  Mar 21, 1980                                            Mad Max
# ...   ..           ...                                                ...
# 5488  89  Dec 31, 2014                           The Sound and the Shadow
# 5487  88   Dec 1, 2015                                   Brooklyn Bizarre
# 5486  87  Aug 11, 2015                     Alleluia! The Devil's Carnival
# 5485  86  Jun 23, 2015                                         Crossroads
# 4765  66  Jan 15, 2013  30 Nights Of Paranormal Activity With The Devi...
#
#      production_budget domestic_gross worldwide_gross
# ...

# %%
df_tn['production_budget'] = df_tn['production_budget'].str.replace(",","")
df_tn['production_budget'] = df_tn['production_budget'].str.replace("$","")
df_tn
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0            425000000   $760,507,625  $2,776,345,279
# ...

# %%
df_tn['worldwide_gross'] = df_tn['worldwide_gross'].str.replace(",","")
df_tn['worldwide_gross'] = df_tn['worldwide_gross'].str.replace("$","")
df_tn
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0            425000000   $760,507,625      2776345279
# ...

# %%
df_tn['worldwide_gross'] = df_tn['worldwide_gross'].astype(int)
df_tn
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross  worldwide_gross
# 0            425000000   $760,507,625       2776345279
# ...

# %%
df_tn['production_budget'] = df_tn['production_budget'].astype(int)
df_tn
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget domestic_gross  worldwide_gross
# 0             425000000      760507625       2776345279
# ...

# %%
df_tn['domestic_gross'] = df_tn['domestic_gross'].str.replace(",","")
df_tn['domestic_gross'] = df_tn['domestic_gross'].str.replace("$","")
df_tn
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget domestic_gross  worldwide_gross
# 0             425000000      760507625       2776345279
# ...

# %%
df_tn['domestic_gross'] = df_tn['domestic_gross'].astype(int)
df_tn
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross
# 0             425000000       760507625       2776345279
# ...

# %%
df_tn['worldwide_profit'] = df_tn['worldwide_gross'] - df_tn['production_budget']

# %%
df_tn = df_tn.dropna(subset=['worldwide_gross'])

# %%
df_tn = df.tn.dropna(subset=['production_budget'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-9f3f53a07868> in <module>
# ----> 1 df_tn = df.tn.dropna(subset=['production_budget'])
#
# NameError: name 'df' is not defined

# %%
df_tn['production_budget'].max()
# Out:
# 425000000

# %%
df_tn['domestic_gross'].max()
# Out:
# 936662225

# %%
df_tn['worldwide_gross'].max()
# Out:
# 2776345279

# %%
df_tn.head(10)
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# 5   6  Dec 18, 2015         Star Wars Ep. VII: The Force Awakens
# 6   7  Apr 27, 2018                       Avengers: Infinity War
# 7   8  May 24, 2007   Pirates of the Caribbean: At Worldâs End
# 8   9  Nov 17, 2017                               Justice League
# 9  10   Nov 6, 2015                                      Spectre
#
#    production_budget  domestic_gross  worldwide_gross  worldwide_profit
# 0          425000000       760507625       2776345279        2351345279
# 1          410600000       241063875       1045663875         635063875
# ...

# %%
type('production_budget')
# Out:
# str

# %%
type('worldwide_gross')
# Out:
# str

# %%
df_tn['worldwide_gross'] = df_tn['worldwide_gross'].astype(int)

# %%
df_tn['production_budget'] = df_tn['production_budget'].astype(int)

# %%
df_tn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5782 entries, 0 to 5781
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   int64
#  4   domestic_gross     5782 non-null   int64
#  5   worldwide_gross    5782 non-null   int64
#  6   worldwide_profit   5782 non-null   int64
# dtypes: int64(5), object(2)
# memory usage: 361.4+ KB

# %%
df_tn['worldwide_profit'].value_counts()
# Out:
# -1000000      24
# -2000000      22
# -500000       20
# -3000000      16
# -250000       15
#               ..
#  3700000       1
# -1601011       1
#  7657973       1
#  622402853     1
#  230400000     1
# Name: worldwide_profit, Length: 5485, dtype: int64

# %%
df_tn['release_date'].value_counts()[:5]
# Out:
# Dec 31, 2014    24
# Dec 31, 2015    23
# Dec 31, 2010    15
# Dec 31, 2008    14
# Dec 31, 2013    13
# Name: release_date, dtype: int64

# %%
scatter_plot_title = 'Relationship Between funds spent and profit'
standing_tackle_label = 'production budget'
sliding_tackle_label = 'worldwide profit'

tackle_figure, ax = plt.subplots(figsize=(10, 6))

ax.set_title('Show_me_the_money')
ax.set_ylabel('total_budget')
ax.set_xlabel('total_earnings')

ax.scatter(df_tn['worldwide_profit'].values, df_tn['production_budget'].values)

# %%
df_tn['worldwide_profit']
# Out:
# 0       2351345279
# 1        635063875
# 2       -200237650
# 3       1072413963
# 4        999721747
#            ...
# 5777         -7000
# 5778        234495
# 5779         -3662
# 5780         -1400
# 5781        179941
# Name: worldwide_profit, Length: 5782, dtype: int64

# %%
#5 most profitable movies = 
top_5_earners
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-fe722a4ce30b> in <module>
#       1 #5 most profitable movies =
# ----> 2 top_5_earners
#
# NameError: name 'top_5_earners' is not defined

# %%
df_imdb
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
df_imdb.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-5c88ed5c82d5> in <module>
# ----> 1 df_imdb.info()
#
# NameError: name 'df_imdb' is not defined

# %%
df_imdb = pd.read_sql("""
    SELECT *
    FROM 
    movie_basics AS mb
        LEFT JOIN movie_ratings AS mr
            ON mb.movie_id = mr.movie_id
""", conn)

# %%
df_imdb[['Genre_1','Genre_2', 'Genre_3']] = df_imdb["genres"].str.split(",",expand=True)

# %%
df_imdb['rating_relative_to_avg'] = df_imdb['averagerating'] - df_imdb['averagerating'].mean()

# %%
df_imdb
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
top_5_earners
# Out:
#     id  release_date                                 movie  production_budget  \
# 0    1  Dec 18, 2009                                Avatar          425000000
# 42  43  Dec 19, 1997                               Titanic          200000000
# 6    7  Apr 27, 2018                Avengers: Infinity War          300000000
# 5    6  Dec 18, 2015  Star Wars Ep. VII: The Force Awakens          306000000
# 33  34  Jun 12, 2015                        Jurassic World          215000000
#
#     domestic_gross  worldwide_gross  worldwide_profit
# 0        760507625       2776345279        2351345279
# 42       659363944       2208208395        2008208395
# 6        678815482       2048134200        1748134200
# 5        936662225       2053311220        1747311220
# 33       652270625       1648854864        1433854864

# %%
df_tn
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross  worldwide_profit
# 0             425000000       760507625       2776345279        2351345279
# ...

# %%
combined_data = df_tn.merge(df_imdb, left_on='movie', right_on='original_title', how='left')

# %%
df_tn['worldwide_profit'] = df_tn['worldwide_gross'] - df_tn['production_budget']

# %%
combined_data
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 6984  78  Dec 31, 2018                                       Red 11
# 6985  79   Apr 2, 1999                                    Following
# 6986  80  Jul 13, 2005                Return to the Land of Wonders
# 6987  81  Sep 29, 2015                         A Plague So Pleasant
# 6988  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross  worldwide_profit  \
# ...

# %%
scatter_plot_title = 'Relationship Between funds earned and average rating'
worldwide_profit_label = 'worldwide profit'
average_rating_label = 'average rating'

x = CD_filtered['worldwide_profit']
y = CD_filtered['averagerating']

average_profit_figure, ax = plt.subplots(figsize=(10, 6))

ax.set_title('what_ratings_say_about_earnings')
ax.set_ylabel('averagerating')
ax.set_xlabel('total_earnings')

ax.scatter(x,y)

# %%
CD_filtered = combined_data[(combined_data['numvotes'] >= 100000) & (combined_data['start_year'] >= 2012)].sort_values('averagerating', ascending=False)

# %%
x = CD_filtered['worldwide_profit']

# %%
df_top10_gen_comb_rat = combined_data[(combined_data['numvotes'] >= 100000) & (combined_data['start_year'] >= 2012)].groupby(['Genre_1', 'Genre_2', 'Genre_3', 'all_genres']).mean().sort_values('averagerating', ascending=False)[:10]

# %%
df_top10_gen_comb_rat
# Out:
#                                                                   id  \
# Genre_1   Genre_2   Genre_3  all_genres
# Adventure Drama     Sci-Fi   Adventure - Drama - Sci-Fi    39.000000
# Biography Drama     Music    Biography - Drama - Music     84.000000
# Drama     Mystery   Sci-Fi   Drama - Mystery - Sci-Fi      62.000000
# Action    Biography Drama    Action - Biography - Drama    67.000000
# Comedy    Drama     Fantasy  Comedy - Drama - Fantasy      95.000000
# Biography Drama     Thriller Biography - Drama - Thriller  51.000000
#                     Romance  Biography - Drama - Romance   35.000000
#           Comedy    Drama    Biography - Comedy - Drama    66.600000
#           Drama     History  Biography - Drama - History   38.333333
# Adventure Drama     Fantasy  Adventure - Drama - Fantasy   53.500000
#
#                                                            production_budget  \
# Genre_1   Genre_2   Genre_3  all_genres
# ...

# %%
combined_data['all_genres'] = combined_data['Genre_1'] + " - " + combined_data['Genre_2'] + " - " + combined_data['Genre_3']

# %%
top_10_profit = combined_data_cleaned.sort_values('worldwide_profit', ascending=False)[:10]

# %%
top_10_profit
# Out:
#      id  release_date                           movie  production_budget  \
# 6     7  Apr 27, 2018          Avengers: Infinity War          300000000
# 33   34  Jun 12, 2015                  Jurassic World          215000000
# 26   27   May 4, 2012                    The Avengers          225000000
# 45   42  Feb 16, 2018                   Black Panther          200000000
# 131  13  Jun 22, 2018  Jurassic World: Fallen Kingdom          170000000
# 178  56  Nov 22, 2013                          Frozen          150000000
# 179  56  Nov 22, 2013                          Frozen          150000000
# 154  35  Mar 17, 2017            Beauty and the Beast          160000000
# 155  35  Mar 17, 2017            Beauty and the Beast          160000000
# 785  73  Jul 10, 2015                         Minions           74000000
#
#      domestic_gross  worldwide_gross  worldwide_profit   movie_id  \
# 6         678815482       2048134200        1748134200  tt4154756
# ...

# %%
combined_data_cleaned = combined_data.dropna(subset=['all_genres'])

# %%
combined_data
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 6984  78  Dec 31, 2018                                       Red 11
# 6985  79   Apr 2, 1999                                    Following
# 6986  80  Jul 13, 2005                Return to the Land of Wonders
# 6987  81  Sep 29, 2015                         A Plague So Pleasant
# 6988  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross  worldwide_profit  \
# ...

# %%
scatter_plot_title = 'Relationship Between funds earned and average rating'
worldwide_profit_label = 'worldwide profit'
average_rating_label = 'genre'

x = top_10_profit['all_genres']
y = df_top10_gen_comb_rat['worldwide_profit']

average_profit_figure, ax = plt.subplots(figsize=(10, 6))

ax.set_title('profit_by_genre')
ax.set_ylabel('genres')
ax.set_xlabel('worldwide_profit')

ax.bar(x, y)
# Out:
# <BarContainer object of 10 artists>

# %%
df_top10_gen_comb_rat.index
# Out:
# MultiIndex([('Adventure',     'Drama',   'Sci-Fi', ...),
#             ('Biography',     'Drama',    'Music', ...),
#             (    'Drama',   'Mystery',   'Sci-Fi', ...),
#             (   'Action', 'Biography',    'Drama', ...),
#             (   'Comedy',     'Drama',  'Fantasy', ...),
#             ('Biography',     'Drama', 'Thriller', ...),
#             ('Biography',     'Drama',  'Romance', ...),
#             ('Biography',    'Comedy',    'Drama', ...),
#             ('Biography',     'Drama',  'History', ...),
#             ('Adventure',     'Drama',  'Fantasy', ...)],
#            names=['Genre_1', 'Genre_2', 'Genre_3', 'all_genres'])

# %%
df_top10_gen_comb_rat.iloc[:,2:3]
# Out:
#                                                            domestic_gross
# Genre_1   Genre_2   Genre_3  all_genres
# Adventure Drama     Sci-Fi   Adventure - Drama - Sci-Fi      2.082258e+08
# Biography Drama     Music    Biography - Drama - Music       2.163033e+08
# Drama     Mystery   Sci-Fi   Drama - Mystery - Sci-Fi        7.268042e+07
# Action    Biography Drama    Action - Biography - Drama      1.286403e+08
# Comedy    Drama     Fantasy  Comedy - Drama - Fantasy        1.532392e+07
# Biography Drama     Thriller Biography - Drama - Thriller    8.896865e+07
#                     Romance  Biography - Drama - Romance     3.589354e+07
#           Comedy    Drama    Biography - Comedy - Drama      5.795499e+07
#           Drama     History  Biography - Drama - History     9.494940e+07
# Adventure Drama     Fantasy  Adventure - Drama - Fantasy     9.442323e+07

# %%
# Out:
#                                      id  production_budget  domestic_gross  \
# Genre_1   Genre_2   Genre_3
# Adventure Drama     Sci-Fi    39.000000       1.365000e+08    2.082258e+08
# Biography Drama     Music     84.000000       5.500000e+07    2.163033e+08
# Drama     Mystery   Sci-Fi    62.000000       8.166667e+07    7.268042e+07
# Action    Biography Drama     67.000000       3.637500e+07    1.286403e+08
# Comedy    Drama     Fantasy   95.000000       1.200000e+07    1.532392e+07
# Biography Comedy    Drama     66.600000       2.140000e+07    5.795499e+07
#           Drama     Romance   35.000000       1.500000e+07    3.589354e+07
#                     Thriller  51.000000       4.112500e+07    8.896865e+07
#                     History   38.333333       3.700000e+07    9.494940e+07
# Adventure Drama     Fantasy   53.500000       6.975000e+07    9.442323e+07
#
#                               worldwide_gross  worldwide_profit   start_year  \
# Genre_1   Genre_2   Genre_3
# ...
